# %%
from siren.utils.squiggletools import *

bulkfile = BulkFile('/home/OXFORDNANOLABS/swibowo/git/bulkvis/notebooks/test.fast5')
# Out:
# ['Channel_50']

# %%
bulkfile.list_channels()
# Out:
# ['Channel_50']

# %%
bulkfile.fetch_squiggle('Channel_50:0-2000')
# Out:
# array([265, 267, 273, ..., 263, 268, 263], dtype=int16)

# %%
bulkfile.fetch_annotation('Channel_50:0-2000')
# Out:
# array([(   0,    0,    0, 200), (   7,    3,    0, 200),
#        (  26,   23,   10,  12), (  26,   26,   23, 200),
#        (  26,   26,   20, 203), (  38,   34,   23, 200),
#        (  57,   57,   43,  11), (  65,   65,   62, 200),
#        (  65,   65,   53, 203), (  72,   72,   62,  11),
#        ( 103,  103,  100, 200), ( 103,  103,   92, 203),
#        ( 111,  111,  100, 200), ( 134,  134,  120,   8),
#        ( 142,  142,  139, 200), ( 142,  142,  130, 203),
#        ( 149,  149,  139,  11), ( 161,  161,  149, 200),
#        ( 180,  180,  169, 203), ( 192,  188,  177, 200),
#        ( 215,  211,  197,   8), ( 249,  249,  249, 200),
#        ( 249,  249,  237, 203), ( 261,  261,  249, 200),
#        ( 280,  280,  269,   8), ( 295,  291,  279,  11),
#        ( 299,  299,  289, 200), ( 322,  322,  309,   8),
#        ( 322,  322,  319, 200), ( 322,  322,  319, 203),
#        ( 330,  330,  319,  11), ( 341,  341,  330, 200),
# ...

# %%
from siren.modules.base import Base
from siren.utils.squiggletools import *






import panel as pn
pn.extension()
pn.extension(notifications=True)

base = Base('/mnt/869990e7-a61f-469f-99fe-a48d24ac44ca/git/bulkvis/notebooks/test.fast5', 'fast5', ['Channel_50'])
base.layout
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='071f6688-95b1-432f-8b2e-ff5b4c6bf67f'>
#   <div id="b48a0cb4-5a12-4472-9bca-ee5cb7fc4e7b" data-root-id="071f6688-95b1-432f-8b2e-ff5b4c6bf67f" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
from siren.utils.squiggletools import BulkFile
file = '/mnt/869990e7-a61f-469f-99fe-a48d24ac44ca/git/PC48A025_20230727_1713_PAQ01914_5D_sequencing_run_07_27_23_RNA004_GM12878_polyA_RNA_4b75ff24_78cb1162.ch50.fast5'
bf = BulkFile(file)
bf.fetch_squiggle('Channel_50:83360-83900')
bf.close()
